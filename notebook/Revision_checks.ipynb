# %%
import pickle
import pandas

with open( '../results/tmp-datafram-b.pickle', 'rb' ) as pickle_file:
    df = pickle.load( pickle_file )

df
# Out:
#                                   perspective  ik-index      ml-index  actual  \
# 1E PERS Middelbeek_Turbulentie        1E PERS  0.857143  9.999841e-01       1
# 1E PERS Gastel_GekniptVoorJou         1E PERS  0.833333  9.999799e-01       1
# 1E PERS Gastel_GekniptVoorJou B       1E PERS  0.750000  9.999745e-01       1
# 1E PERS Gastel_ZwaarVerliefd!         1E PERS  0.758621  9.999743e-01       1
# 1E PERS Moelands_Weerloos C           1E PERS  0.852941  9.999707e-01       1
# ...                                       ...       ...           ...     ...
# 3E PERS Lackberg_Vuurtorenwachter     3E PERS  0.000000  1.302445e-06       3
# 3E PERS Paolini_Erfenis C             3E PERS  0.000000  9.201639e-07       3
# 3E PERS Rijn_BlueCuracao B            3E PERS  0.000000  7.477593e-07       3
# 3E PERS Balducci_DieZomer             3E PERS  0.000000  6.893841e-07       3
# 3E PERS Kelly_EensInJe B              3E PERS  0.000000  4.462015e-07       3
#
# ...

# %%
df[ [ 'Leesclub' in idx for idx in df.index ] ]
# Out:
#                               perspective  ik-index  ml-index  actual  \
# 1E PERS Dorrestein_Leesclub       1E PERS  0.636364  0.923945       1
# 1E PERS Dorrestein_Leesclub B     1E PERS  0.733333  0.840156       1
#
#                                ik-index-prediction  F1-ik-index  \
# 1E PERS Dorrestein_Leesclub                      1     0.681905
# 1E PERS Dorrestein_Leesclub B                    1     0.465632
#
#                                ml-index-prediction  F1-ml-index  ml-correct  \
# 1E PERS Dorrestein_Leesclub                      1     0.885668           1
# 1E PERS Dorrestein_Leesclub B                    1     0.915361           1
#
#                                ik-correct     ml-color ik-color
# 1E PERS Dorrestein_Leesclub             1  deepskyblue   orange
# 1E PERS Dorrestein_Leesclub B           1  deepskyblue   orange
